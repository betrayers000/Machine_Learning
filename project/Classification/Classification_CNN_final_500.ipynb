# %% [markdown]
# # Classification_CNN

# %% [markdown]
# ## Method
#
# Build Convolutional Neural Network model with Tensorflow-Keras.
#
# ```
# X_train: 50000 samples
# X_test: 10000 samples
#
# batch_size: 128
# epochs: 100
# ```

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Load dataset, Preprocessing

# %%
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Convolution2D, MaxPooling2D, Flatten, Dropout
from sklearn.metrics import accuracy_score

# %%
output_dim = nb_classes = 10
input_dim = (32,32,3)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
Y_train = utils.to_categorical(y_train, nb_classes)
Y_test = utils.to_categorical(y_test, nb_classes)

# %%
print(input_dim, X_train.shape, Y_train.shape, X_test.shape, Y_test.shape, output_dim)
# Out:
# (32, 32, 3) (50000, 32, 32, 3) (50000, 10) (10000, 32, 32, 3) (10000, 10) 10

# %% [markdown]
# ## Build Model

# %% [markdown]
# ## arch2 Image augmentation 2

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu'))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))

# # 14,14
model.add(Convolution2D(24,1, activation='relu'))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Convolution2D(64, 1, activation='relu'))

model.add(Convolution2D(256,(3,3), activation='relu'))
model.add(BatchNormalization())

model.add(Convolution2D(10, 4))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten (Flatten)            (None, 10)                0
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 110s 282ms/step - loss: 1.6119 - accuracy: 0.4441 - val_loss: 1.4521 - val_accuracy: 0.4957
# Epoch 2/50
# 390/390 [==============================] - 105s 268ms/step - loss: 1.2059 - accuracy: 0.5808 - val_loss: 1.3732 - val_accuracy: 0.5247
# Epoch 3/50
# 390/390 [==============================] - 105s 268ms/step - loss: 1.0441 - accuracy: 0.6366 - val_loss: 1.1833 - val_accuracy: 0.5946
# Epoch 4/50
# 390/390 [==============================] - 105s 269ms/step - loss: 0.9469 - accuracy: 0.6712 - val_loss: 1.0639 - val_accuracy: 0.6416
# Epoch 5/50
# 390/390 [==============================] - 104s 267ms/step - loss: 0.8679 - accuracy: 0.6947 - val_loss: 0.9902 - val_accuracy: 0.6664
# Epoch 6/50
# 390/390 [==============================] - 104s 267ms/step - loss: 0.8096 - accuracy: 0.7175 - val_loss: 0.8953 - val_accuracy: 0.6920
# Epoch 7/50
# 390/390 [==============================] - 104s 266ms/step - loss: 0.
# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %%
predictions = model.predict_classes(X_test)

# %% [markdown]
# ## arch 4 - Image augmentation (4) && Dropout

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu'))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu'))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu'))

model.add(Convolution2D(256,(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 116s 298ms/step - loss: 2.1930 - accuracy: 0.2980 - val_loss: 1.7167 - val_accuracy: 0.4104
# Epoch 2/50
# 390/390 [==============================] - 117s 299ms/step - loss: 1.8162 - accuracy: 0.4041 - val_loss: 1.5980 - val_accuracy: 0.4491
# Epoch 3/50
# 390/390 [==============================] - 116s 298ms/step - loss: 1.6828 - accuracy: 0.4504 - val_loss: 1.6929 - val_accuracy: 0.4500
# Epoch 4/50
# 390/390 [==============================] - 116s 298ms/step - loss: 1.6002 - accuracy: 0.4777 - val_loss: 1.5850 - val_accuracy: 0.4854
# Epoch 5/50
# 390/390 [==============================] - 116s 299ms/step - loss: 1.5423 - accuracy: 0.4996 - val_loss: 1.2556 - val_accuracy: 0.5676
# Epoch 6/50
# 390/390 [==============================] - 117s 299ms/step - loss: 1.4542 - accuracy: 0.5216 - val_loss: 1.4239 - val_accuracy: 0.5422
# Epoch 7/50
# 390/390 [==============================] - 115s 295ms/step - loss: 1.4024 - accuracy: 0.5422 - val_loss: 1.3743 - val_accuracy: 0.5593
# Epoch 8/50
# 390/390 [==============================] - 116s 298ms/step - loss: 1.3503 - accuracy: 0.5591 - val_loss: 1.6264 - val_accuracy: 0.5129
# Epoch 9/50
# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %%
predictions = model.predict_classes(X_test)

# %% [markdown]
# ## arch 4 - Image augmentation (4) && Dropout && L2 Regularization (0.1)

# %%
from tensorflow.keras import regularizers

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.1), input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.1)))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu', kernel_regularizer=regularizers.l2(0.1)))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.1), padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(0.1)))

model.add(Convolution2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.1)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4, kernel_regularizer=regularizers.l2(0.1),))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 121s 311ms/step - loss: 21.3552 - accuracy: 0.3314 - val_loss: 10.3848 - val_accuracy: 0.1602
# Epoch 2/50
# 390/390 [==============================] - 121s 311ms/step - loss: 5.6396 - accuracy: 0.4761 - val_loss: 4.0488 - val_accuracy: 0.2072
# Epoch 3/50
# 390/390 [==============================] - 121s 310ms/step - loss: 2.3755 - accuracy: 0.5370 - val_loss: 2.2571 - val_accuracy: 0.4216
# Epoch 4/50
# 390/390 [==============================] - 121s 310ms/step - loss: 1.6831 - accuracy: 0.5685 - val_loss: 1.5993 - val_accuracy: 0.5699
# Epoch 5/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.5206 - accuracy: 0.5850 - val_loss: 1.9179 - val_accuracy: 0.5019
# Epoch 6/50
# 390/390 [==============================] - 120s 308ms/step - loss: 1.4715 - accuracy: 0.5985 - val_loss: 1.5979 - val_accuracy: 0.5821
# Epoch 7/50
# 390/390 [==============================] - 122s 312ms/step - loss: 1.4469 - accuracy: 0.6058 - val_loss: 1.8486 - val_accuracy: 0.4731
# Epoch 8/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.4196 - accuracy: 0.6209 - val_loss: 2.3452 - val_accuracy: 0.3409
# Epoch 9/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.4182 - accuracy: 0.6257 - val_loss: 1.9926 - val_accuracy: 0.4343
# Epoch 10/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1
50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.3683 - accuracy: 0.6604 - val_loss: 1.7252 - val_accuracy: 0.5595
# Epoch 40/50
# 390/390 [==============================] - 120s 308ms/step - loss: 1.3623 - accuracy: 0.6610 - val_loss: 1.9860 - val_accuracy: 0.5309
# Epoch 41/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.3799 - accuracy: 0.6569 - val_loss: 1.5774 - val_accuracy: 0.6124
# Epoch 42/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3797 - accuracy: 0.6581 - val_loss: 1.5040 - val_accuracy: 0.6212
# Epoch 43/50
# 390/390 [==============================] - 119s 304ms/step - loss: 1.3665 - accuracy: 0.6600 - val_loss: 1.5270 - val_accuracy: 0.6006
# Epoch 44/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3652 - accuracy: 0.6618 - val_loss: 2.6421 - val_accuracy: 0.3711
# Epoch 45/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3635 - accuracy: 0.6619 - val_loss: 1.4496 - val_accuracy: 0.6380
# Epoch 46/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3686 - accuracy: 0.6652 - val_loss: 1.6336 - val_accuracy: 0.5682
# Epoch 47/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.3635 - accuracy: 0.6634 - val_loss: 1.2510 - val_accuracy: 0.7036
# Epoch 48/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3637 - accuracy: 0.6634 - val_loss: 1.5443 - val_accuracy: 0.6069
# Epoch 49/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.3641 - accuracy: 0.6635 - val_loss: 1.7692 - val_accuracy: 0.5623
# Epoch 50/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.3631 - accuracy: 0.6617 - val_loss: 4.5109 - val_accuracy: 0.1999

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %%
y_pred = model.predict_classes(X_test)

# %%
y_pred = model.predict_classes(X_test)
score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.1999

# %% [markdown]
# ## arch 5 - Image augmentation (4) && Dropout && L2 Regularization (0.01)

# %%
from tensorflow.keras import regularizers

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01), padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(0.01)))

model.add(Convolution2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4, kernel_regularizer=regularizers.l2(0.01),))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_50 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 122s 312ms/step - loss: 5.6566 - accuracy: 0.3072 - val_loss: 12.6401 - val_accuracy: 0.1254
# Epoch 42/50
# 390/390 [==============================] - 121s 309ms/step - loss: 0.8488 - accuracy: 0.7792 - val_loss: 0.8795 - val_accuracy: 0.7730
# Epoch 43/50
# 390/390 [==============================] - 121s 310ms/step - loss: 0.8422 - accuracy: 0.7827 - val_loss: 0.9816 - val_accuracy: 0.7485
# Epoch 44/50
# 390/390 [==============================] - 123s 314ms/step - loss: 0.8445 - accuracy: 0.7806 - val_loss: 0.9079 - val_accuracy: 0.7793
# Epoch 45/50
# 390/390 [==============================] - 124s 317ms/step - loss: 0.8389 - accuracy: 0.7845 - val_loss: 0.9326 - val_accuracy: 0.7691
# Epoch 46/50
# 390/390 [==============================] - 121s 311ms/step - loss: 0.8349 - accuracy: 0.7841 - val_loss: 1.0109 - val_accuracy: 0.7351
# Epoch 47/50
# 390/390 [==============================] - 121s 309ms/step - loss: 0.8356 - accuracy: 0.7836 - val_loss: 0.8676 - val_accuracy: 0.7791
# Epoch 48/50
# 390/390 [==============================] - 120s 308ms/step - loss: 0.8341 - accuracy: 0.7844 - val_loss: 0.8968 - val_accuracy: 0.7794
# Epoch 49/50
# 390/390 [==============================] - 120s 309ms/step - loss: 0.8361 - accuracy: 0.7856 - val_loss: 1.0642 - val_accuracy: 0.7312
# Epoch 50/50
# 390/390 [==============================] - 120s 309ms/step - loss: 0.8257 - accuracy: 0.7890 - val_loss: 0.9241 - val_accuracy: 0.7639

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %% [markdown]
# # ------

# %% [markdown]
# ## arch 6 - Image augmentation (4) && Dropout && L2 Regularization (0.001)

# %%
from tensorflow.keras import regularizers

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu', kernel_regularizer=regularizers.l2(0.001)))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(0.001)))

model.add(Convolution2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4, kernel_regularizer=regularizers.l2(0.001),))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_58 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 125s 322ms/step - loss: 2.5576 - accuracy: 0.3092 - val_loss: 2.1525 - val_accuracy: 0.3691
# Epoch 2/50
# 390/390 [==============================] - 121s 311ms/step - loss: 2.1948 - accuracy: 0.4012 - val_loss: 2.0841 - val_accuracy: 0.4575
# Epoch 3/50
# 390/390 [==============================] - 121s 309ms/step - loss: 2.0617 - accuracy: 0.4458 - val_loss: 2.0524 - val_accuracy: 0.4724
# Epoch 4/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.9684 - accuracy: 0.4747 - val_loss: 1.8259 - val_accuracy: 0.5115
# Epoch 5/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.8698 - accuracy: 0.5033 - val_loss: 1.6191 - val_accuracy: 0.5738
# Epoch 6/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.7954 - accuracy: 0.5290 - val_loss: 1.8105 - val_accuracy: 0.5455
# Epoch 7/50
# 390/390 [==============================] - 121s 310ms/step - loss: 1.7319 - accuracy: 0.5444 - val_loss: 1.6644 - val_accuracy: 0.5813
# Epoch 8/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.6909 - accuracy: 0.5584 - val_loss: 1.8386 - val_accuracy: 0.5551
# Epoch 9/50
# 390/390 [==============================] - 121s 309ms/step - loss: 1.6565 - accuracy: 0.5692 - val_loss: 1.6349 - val_accuracy: 0.5808
# Epoch 10/50
# 390/390 [==============================] - 121s 311ms/step - loss: 1.5921 - accuracy: 0.5785 - val_loss: 1.3887 - val_accuracy: 0.6339
# Epoch 11/50
# 390/390 [==============================] - 121s 309ms/step - loss: 1.5187 - accuracy: 0.5872 - val_loss: 1.5273 - val_accuracy: 0.6101
# Epoch 12/50
# 390/390 [==============================] - 121s 310ms/step - loss: 1.4557 - accuracy: 0.6061 - val_loss: 1.2927 - val_accuracy: 0.6686
# Epoch 13/50
# 390/390 [==============================] - 120s 308ms/step - loss: 1.4228 - accuracy: 0.6128 - val_loss: 1.4966 - val_accuracy: 0.6187
# Epoch 14/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3876 - accuracy: 0.6218 - val_loss: 1.4480 - val_accuracy: 0.6326
# Epoch 15/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3516 - accuracy: 0.6351 - val_loss: 1.4573 - val_accuracy: 0.6279
# Epoch 16/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3267 - accuracy: 0.6397 - val_loss: 1.3194 - val_accuracy: 0.6610
# Epoch 17/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.2987 - accuracy: 0.6502 - val_loss: 1.4620 - val_accuracy: 0.6251
# Epoch 18/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.2847 - accuracy: 0.6533 - val_loss: 1.4283 - val_accuracy: 0.6274
# Epoch 19/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.2582 - accuracy: 0.6612 - val_loss: 1.4461 - val_accuracy: 0.6319
# Epoch 20/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.2350 - accuracy: 0.6663 - val_loss: 1.1808 - val_accuracy: 0.6966
# Epoch 21/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.2140 - accuracy: 0.6734 - val_loss: 1.4053 - val_accuracy: 0.6553
# Epoch 22/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.1967 - accuracy: 0.6797 - val_loss: 1.2878 - val_accuracy: 0.6743
# Epoch 23/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.1724 - accuracy: 0.6857 - val_loss: 1.3366 - val_accuracy: 0.6692
# Epoch 24/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.1650 - accuracy: 0.6876 - val_loss: 1.1438 - val_accuracy: 0.7179
# Epoch 25/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.1415 - accuracy: 0.6970 - val_loss: 1.1757 - val_accuracy: 0.7047
# Epoch 26/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.1266 - accuracy: 0.6978 - val_loss: 1.1985 - val_accuracy: 0.7018
# Epoch 27/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.1146 - accuracy: 0.7050 - val_loss: 1.3496 - val_accuracy: 0.6621
# Epoch 28/50
# 390/390 [==============================] - 120s 306ms/step - loss: 1.0953 - accuracy: 0.7078 - val_loss: 1.1717 - val_accuracy: 0.7079
# Epoch 29/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.0832 - accuracy: 0.7114 - val_loss: 1.0793 - val_accuracy: 0.7285
# Epoch 30/50
# 390/390 [==============================] - 120s 306ms/step - loss: 1.0713 - accuracy: 0.7147 - val_loss: 1.2392 - val_accuracy: 0.6889
# Epoch 31/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.0642 - accuracy: 0.7161 - val_loss: 1.0411 - val_accuracy: 0.7425
# Epoch 32/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.0457 - accuracy: 0.7240 - val_loss: 1.0390 - val_accuracy: 0.7396
# Epoch 33/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.0368 - accuracy: 0.7238 - val_loss: 1.2131 - val_accuracy: 0.7022
# Epoch 34/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.0271 - accuracy: 0.7262 - val_loss: 1.0620 - val_accuracy: 0.7390
# Epoch 35/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.0180 - accuracy: 0.7288 - val_loss: 1.1250 - val_accuracy: 0.7132
# Epoch 36/50
# 390/390 [==============================] - 120s 307ms/step - loss: 0.9994 - accuracy: 0.7344 - val_loss: 1.0147 - val_accuracy: 0.7482
# Epoch 37/50
# 390/390 [==============================] - 119s 305ms/step - loss: 0.9936 - accuracy: 0.7347 - val_loss: 1.0530 - val_accuracy: 0.7347
# Epoch 38/50
# 390/390 [==============================] - 120s 308ms/step - loss: 0.9842 - accuracy: 0.7361 - val_loss: 0.9960 - val_accuracy: 0.7558
# Epoch 39/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9728 - accuracy: 0.7420 - val_loss: 1.0554 - val_accuracy: 0.7430
# Epoch 40/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9542 - accuracy: 0.7470 - val_loss: 1.0069 - val_accuracy: 0.7488
# Epoch 41/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9588 - accuracy: 0.7427 - val_loss: 1.0289 - val_accuracy: 0.7449
# Epoch 42/50
# 390/390 [==============================] - 119s 305ms/step - loss: 0.9417 - accuracy: 0.7485 - val_loss: 1.0025 - val_accuracy: 0.7542
# Epoch 43/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9382 - accuracy: 0.7492 - val_loss: 1.2176 - val_accuracy: 0.6888
# Epoch 44/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9264 - accuracy: 0.7542 - val_loss: 0.9726 - val_accuracy: 0.7547
# Epoch 45/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.9111 - accuracy: 0.7565 - val_loss: 0.9131 - val_accuracy: 0.7721
# Epoch 46/50
# 390/390 [==============================] - 120s 307ms/step - loss: 0.9136 - accuracy: 0.7556 - val_loss: 1.0215 - val_accuracy: 0.7456
# Epoch 47/50
# 390/390 [==============================] - 120s 306ms/step - loss: 0.9026 - accuracy: 0.7574 - val_loss: 1.0590 - val_accuracy: 0.7354
# Epoch 48/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.8975 - accuracy: 0.7610 - val_loss: 0.9860 - val_accuracy: 0.7589
# Epoch 49/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.8908 - accuracy: 0.7634 - val_loss: 1.0485 - val_accuracy: 0.7387
# Epoch 50/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.8788 - accuracy: 0.7653 - val_loss: 0.8839 - val_accuracy: 0.7875

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %%
predictions = model.predict_classes(X_test)

# %% [markdown]
# ## arch 7 - Image augmentation (4) && Dropout && L2 Regularization (0.0001)

# %%
from tensorflow.keras import regularizers

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.0001), input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.0001)))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu', kernel_regularizer=regularizers.l2(0.0001)))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.0001), padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(0.0001)))

model.add(Convolution2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4, kernel_regularizer=regularizers.l2(0.0001),))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_66 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=50,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/50
# 390/390 [==============================] - 119s 305ms/step - loss: 2.1651 - accuracy: 0.3109 - val_loss: 1.7186 - val_accuracy: 0.4208
# Epoch 2/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.8696 - accuracy: 0.4052 - val_loss: 1.6801 - val_accuracy: 0.4815
# Epoch 3/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.7434 - accuracy: 0.4442 - val_loss: 1.7516 - val_accuracy: 0.4924
# Epoch 4/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.6565 - accuracy: 0.4750 - val_loss: 1.8401 - val_accuracy: 0.4678
# Epoch 5/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.6153 - accuracy: 0.4878 - val_loss: 1.7922 - val_accuracy: 0.4787
# Epoch 6/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.5112 - accuracy: 0.5182 - val_loss: 1.6863 - val_accuracy: 0.5013
# Epoch 7/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.4560 - accuracy: 0.5390 - val_loss: 1.3049 - val_accuracy: 0.5685
# Epoch 8/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.4305 - accuracy: 0.5495 - val_loss: 1.5315 - val_accuracy: 0.5164
# Epoch 9/50
# 390/390 [==============================] - 120s 308ms/step - loss: 1.3842 - accuracy: 0.5521 - val_loss: 1.6884 - val_accuracy: 0.4628
# Epoch 10/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.3146 - accuracy: 0.5685 - val_loss: 1.5895 - val_accuracy: 0.5296
# Epoch 11/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1.2468 - accuracy: 0.5901 - val_loss: 1.3122 - val_accuracy: 0.5846
# Epoch 12/50
# 390/390 [==============================] - 120s 307ms/step - loss: 1.2281 - accuracy: 0.5975 - val_loss: 1.2529 - val_accuracy: 0.5987
# Epoch 13/50
# 390/390 [==============================] - 120s 308ms/step - loss: 1.1949 - accuracy: 0.6091 - val_loss: 1.2925 - val_accuracy: 0.5943
# Epoch 14/50
# 390/390 [==============================] - 119s 305ms/step - loss: 1.1697 - accuracy: 0.6153 - val_loss: 1.3225 - val_accuracy: 0.6121
# Epoch 15/50
# 390/390 [==============================] - 119s 306ms/step - loss: 1
50
# 390/390 [==============================] - 120s 307ms/step - loss: 0.7965 - accuracy: 0.7338 - val_loss: 0.9128 - val_accuracy: 0.7251
# Epoch 44/50
# 390/390 [==============================] - 120s 307ms/step - loss: 0.7952 - accuracy: 0.7371 - val_loss: 0.7978 - val_accuracy: 0.7532
# Epoch 45/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.7964 - accuracy: 0.7349 - val_loss: 0.8276 - val_accuracy: 0.7414
# Epoch 46/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.7833 - accuracy: 0.7400 - val_loss: 0.7816 - val_accuracy: 0.7601
# Epoch 47/50
# 390/390 [==============================] - 119s 305ms/step - loss: 0.7758 - accuracy: 0.7416 - val_loss: 0.8199 - val_accuracy: 0.7482
# Epoch 48/50
# 390/390 [==============================] - 120s 307ms/step - loss: 0.7782 - accuracy: 0.7403 - val_loss: 0.8508 - val_accuracy: 0.7412
# Epoch 49/50
# 390/390 [==============================] - 120s 308ms/step - loss: 0.7628 - accuracy: 0.7451 - val_loss: 0.7722 - val_accuracy: 0.7626
# Epoch 50/50
# 390/390 [==============================] - 119s 306ms/step - loss: 0.7623 - accuracy: 0.7483 - val_loss: 0.8229 - val_accuracy: 0.7481

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %% [markdown]
# ## arch 7 - Image augmentation (4) && Dropout && L2 Regularization (0.001) + 500epochs

# %%
from tensorflow.keras import regularizers

# %%
model = Sequential()

# 32,32
model.add(Convolution2D(16,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(32,32,3), padding='same'))
model.add(BatchNormalization())

# 30,30
model.add(Convolution2D(32,(3,3), activation='relu' , kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())

# 28,28
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# # 14,14
model.add(Convolution2D(24,1, activation='relu', kernel_regularizer=regularizers.l2(0.001)))

# 14,14
model.add(Convolution2D(64,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001), padding='same'))
model.add(BatchNormalization())

# 12, 12
model.add(Convolution2D(128,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(0.001)))

model.add(Convolution2D(256,(3,3), activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Convolution2D(10, 4, kernel_regularizer=regularizers.l2(0.001),))

model.add(Flatten())
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_74 (Conv2D)           (None, 32, 32, 16)        448
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 32, 32, 16)        64
# _________________________________________________________________
# conv2d_75 (Conv2D)           (None, 30, 30, 32)        4640
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_76 (Conv2D)           (None, 15, 15, 24)        792
# _________________________________________________________________
# conv2d_77 (Conv2D)           (None, 15, 15, 64)        13888
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 15, 15, 64)        256
# _________________________________________________________________
# conv2d_78 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 6, 6, 64)          8256
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 4, 4, 256)         147712
# _________________________________________________________________
# batch_normalization_51 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 1, 1, 10)          40970
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 292,546
# Trainable params: 291,554
# Non-trainable params: 992
# _________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    zoom_range=0.15,
    width_shift_range=0.2
    
)
batch_size = 128
model_info = model.fit_generator(
    datagen.flow(X_train, Y_train, batch_size=batch_size),
    steps_per_epoch=X_train.shape[0]//batch_size,
    epochs=500,
    validation_data=(X_test, Y_test),
)
# Out:
# Epoch 1/500
# 390/390 [==============================] - 120s 307ms/step - loss: 2.5120 - accuracy: 0.3118 - val_loss: 2.0742 - val_accuracy: 0.4390
# Epoch 2/500
# 390/390 [==============================] - 119s 306ms/step - loss: 2.1228 - accuracy: 0.4133 - val_loss: 2.0533 - val_accuracy: 0.4275
# Epoch 3/500
# 390/390 [==============================] - 119s 306ms/step - loss: 1.9926 - accuracy: 0.4506 - val_loss: 1.8378 - val_accuracy: 0.4722
# Epoch 4/500
# 390/390 [==============================] - 119s 306ms/step - loss: 1.9326 - accuracy: 0.4780 - val_loss: 1.9214 - val_accuracy: 0.4652
# Epoch 5/500
# 390/390 [==============================] - 119s 306ms/step - loss: 1
500
# 390/390 [==============================] - 122s 312ms/step - loss: 0.4611 - accuracy: 0.8758 - val_loss: 0.5463 - val_accuracy: 0.8684
# Epoch 490/500
# 390/390 [==============================] - 123s 316ms/step - loss: 0.4599 - accuracy: 0.8761 - val_loss: 0.5601 - val_accuracy: 0.8704
# Epoch 491/500
# 390/390 [==============================] - 124s 318ms/step - loss: 0.4602 - accuracy: 0.8760 - val_loss: 0.5375 - val_accuracy: 0.8644
# Epoch 492/500
# 390/390 [==============================] - 121s 311ms/step - loss: 0.4574 - accuracy: 0.8786 - val_loss: 0.5466 - val_accuracy: 0.8636
# Epoch 493/500
# 390/390 [==============================] - 121s 309ms/step - loss: 0.4556 - accuracy: 0.8806 - val_loss: 0.5537 - val_accuracy: 0.8629
# Epoch 494/500
# 390/390 [==============================] - 125s 321ms/step - loss: 0.4655 - accuracy: 0.8761 - val_loss: 0.6190 - val_accuracy: 0.8494
# Epoch 495/500
# 390/390 [==============================] - 122s 312ms/step - loss: 0.4582 - accuracy: 0.8796 - val_loss: 0.6140 - val_accuracy: 0.8455
# Epoch 496/500
# 390/390 [==============================] - 121s 310ms/step - loss: 0.4550 - accuracy: 0.8805 - val_loss: 0.6020 - val_accuracy: 0.8499
# Epoch 497/500
# 390/390 [==============================] - 120s 308ms/step - loss: 0.4645 - accuracy: 0.8745 - val_loss: 0.5006 - val_accuracy: 0.8781
# Epoch 498/500
# 390/390 [==============================] - 121s 309ms/step - loss: 0.4591 - accuracy: 0.8763 - val_loss: 0.7178 - val_accuracy: 0.8231
# Epoch 499/500
# 390/390 [==============================] - 122s 312ms/step - loss: 0.4561 - accuracy: 0.8803 - val_loss: 0.5967 - val_accuracy: 0.8590
# Epoch 500/500
# 390/390 [==============================] - 126s 322ms/step - loss: 0.4569 - accuracy: 0.8780 - val_loss: 0.6308 - val_accuracy: 0.8504

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'],'r')
plt.plot(model_info.history['val_accuracy'],'b')
plt.legend({'training accuracy':'r', 'validation accuracy': 'b'})
plt.show()

# %%
plt.plot(model_info.history['loss'],'r')
plt.plot(model_info.history['val_loss'],'b')
plt.legend({'training loss':'r', 'validation loss': 'b'})
plt.show()

# %%
predictions = model.predict_classes(X_test)

# %%
import numpy as np
y_test = np.argmax(Y_test, axis=1)

# %%
index = 0
misclassifiedIndexes = []
for label, predict in zip(y_test, predictions):
    if label != predict: 
        misclassifiedIndexes.append(index)
    index +=1
X_test_mis = X_test.astype('uint8')

# %%
plt.figure(figsize=(20,4))
for plotIndex, badIndex in enumerate(misclassifiedIndexes[0:5]):
    plt.subplot(1, 5, plotIndex + 1)
    plt.imshow(X_test_mis[badIndex])
    plt.title('Predicted: {}, Actual: {}'.format(predictions[badIndex], y_test[badIndex]), fontsize = 15)

# %%
from sklearn.metrics import confusion_matrix 
import seaborn as sns
# we can also use a confusion matrix to visualize the performance of a classification model
cm = confusion_matrix(y_test, predictions)
# use this line to normalize the confusion matrix to show percentages instead of counts
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
# plot this matrix
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Overall Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
plt.savefig('toy_Digits_ConfusionSeabornCodementor.png')
plt.show();
